# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="mistral-small-latest")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There is no official capital of the Moon, as the Moon is not a sovereign nation or a country with a government. However, if we consider the concept humorously or metaphorically, some fun possibilities could include:
#
# 1. **The Armstrong Base** – A playful nod to Neil Armstrong, the first human to set foot on the Moon (Apollo 11, 1969).
# 2. **Lunar City** – A generic term for the first permanent human settlement on the Moon.
# 3. **Copernicus Crater** – A famous lunar landmark named after the astronomer Nicolaus Copernicus.
# 4. **The Sea of Tranquility** – Where Apollo 11 landed, making it a historic "capital" of sorts.
# 5. **Lunar Gateway** – A planned space station orbiting the Moon, which could serve as a hub for future lunar activities.
#
# Would you like a more serious or scientific answer, or are you just looking for fun? 😊

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="mistral-small-latest",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Welcome to Nova Solis, the Capital of the Moon**
#
# Perched on the rim of the Shackleton Crater near the lunar South Pole, **Nova Solis** gleams as a marvel of human ingenuity and lunar ambition. This city isn’t just a settlement—it’s a testament to humanity’s expansion beyond Earth, a beacon of science, governance, and culture in the void of space.
#
# ### **Geography and Environment**
# Nova Solis is built within a series of interconnected, pressurized domes and subterranean tunnels, leveraging the Moon’s natural resources:
# - **Energy:** Solar arrays cover the crater’s rim, bathed in near-constant sunlight, while deep beneath the surface, nuclear reactors provide backup power.
# - **Water:** Mined from permanently shadowed regions of Shackleton Crater, water is a precious resource, carefully recycled in a near-closed loop system.
# - **Location:** Chosen for its near-constant sunlight (for energy) and proximity to suspected water ice deposits (for survival).
#
# ### **Architecture and Design**
# The city’s architecture blends futuristic aesthetics with lunar practicality:
# - **The Central Spire:** A towering, transparent structure housing the **Lunar Assembly Hall**, where representatives from Earth’s governments and lunar colonies debate policy under a simulated sky.
# - **Residential Zones:** Modular habitats with artificial gravity sections for long-term comfort, surrounded by hydroponic gardens and communal spaces.
# - **Industrial Sector:** Factories and labs process regolith into metals, ceramics, and oxygen, while 3D printers construct new structures from lunar materials.
# - **Cultural Hub:** The **Lunar Athenaeum**, a vast library and museum preserving Earth’s history and the Moon’s future, alongside art galleries and performance halls.
#
# ### **Governance and Society**
# Nova Solis is a **self-governing city-state**, under the **Lunar Accord**—a treaty ratified by Earth’s nations and corporate entities. Its leadership includes:
# - **The Lunar Chancellor:** Elected by the citizens, overseeing diplomacy and administration.
# - **The Council of Domes:** Representatives from different lunar industries and colonies, ensuring fair resource distribution.
# - **The Arbiters:** A judicial body that handles disputes, including those between Earth and lunar interests.
#
# Society is a mix of scientists, engineers, artists, miners, and diplomats—all united by the shared dream of a multi-planetary future.
#
# ### **Economy and Trade**
# Nova Solis thrives as a hub for:
# - **Helium-3 Mining:** A rare isotope essential for fusion energy, mined from lunar regolith and exported to Earth.
# - **Tourism:** Luxury orbital hotels and guided tours of the Moon’s surface attract adventurers and scientists alike.
# - **Research:** A global leader in exobiology, robotics, and low-gravity physics, collaborating with Earth’s best minds.
#
# ### **Challenges and Threats**
# - **Radiation:** Despite shielding, solar flares and cosmic rays pose risks, requiring constant monitoring.
# - **Political Tensions:** Disputes over resource rights and Earth’s influence occasionally flare up.
# - **Supply Dependence:** While largely self-sufficient, Nova Solis still relies on Earth for certain high-tech goods and cultural exchange.
#
# ### **The Future of Nova Solis**
# With plans to expand into **Lunar City 2** (a sister settlement near the Marius Hills) and eventual independence from Earth, Nova Solis stands as the first true **off-world capital**—a symbol of humanity’s next great leap.
#
# **Would you like to explore a specific aspect of Nova Solis further?** Perhaps its history, daily life, or a particular conflict? Or maybe you'd like to imagine visiting this city?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="mistral-small-latest",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaris

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="mistral-small-latest",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Name:** New Selene
#
# **Location:** The Earth-facing side of the Moon, built within and atop the lava tubes of **Mare Imbrium**, providing natural radiation shielding and structural stability.
#
# **Vibe:** *Gleaming, high-tech, lunar*
#
# **Economy:**
# - **Helium-3 mining** (for fusion energy)
# - **Lunar tourism & luxury habitats**
# - **Zero-gravity manufacturing** (advanced materials, pharmaceuticals)
# - **Research & defense hub** (interplanetary coordination, military outpost)
# - **Spaceport commerce** (refueling, shipbuilding, trade hub)
#
# *Bonus:* The city’s skyline is dominated by **The Spire**, a kilometer-high orbital elevator connecting New Selene to Earth and beyond.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='mistral-small-latest',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunar Prime', location='Sea of Tranquility, The Moon', vibe='A gleaming metropolis of cutting-edge technology and raw lunar beauty, where towering spires reach toward Earth and domed gardens thrive under artificial skies.', economy='Helium-3 mining, zero-gravity manufacturing, interplanetary trade, and research grants.')

# %%
response
# Out:
# {'messages': [HumanMessage(content='What is the capital of The Moon?', additional_kwargs={}, response_metadata={}, id='cede0616-d416-4888-98ec-c9fca6f5da64'),
#   AIMessage(content="The capital of the Moon is **Lunar Prime**, a gleaming metropolis nestled within the **Sea of Tranquility**. It is a city of contrasts—where cutting-edge technology meets the raw beauty of the lunar landscape. The city is built into the rim of a vast, ancient crater, with towering spires of carbon-fiber and graphene reaching toward the Earth, which hangs perpetually in the sky like a blue marble.\n\nLunar Prime is a hub of scientific research, commerce, and governance for the Moon's colonies. Its economy thrives on **helium-3 mining**, **zero-gravity manufacturing**, and **interplanetary trade**. The city is also a cultural crossroads, with domed gardens, art installations that float in low gravity, and virtual reality hubs that simulate Earth's environments.\n\nWould you like me to generate more details about Lunar Prime? For example, its architecture, key landmarks, or how its society functions? Let me know! Otherwise, I can create another capital city for you. Just say the word. 🌕✨\n\n*(Note: If you'd like a different vibe or location for the Moon's capital, let me know!)* 😊\n\n---\n**Example of how I can expand:**\n- **Architecture:** Spiral towers that rotate to simulate gravity, bridges made of self-repairing nanomaterials, and habitats buried under regolith for radiation shielding.\n- **Landmarks:** The **Earthview Observatory**, where residents gather to watch their home planet; the **Lunar Bazaar**, a market floating in low gravity; and the **Tranquility Spire**, a monument to humanity's first steps on the Moon.\n- **Society:** A mix of scientists, engineers, artists, and diplomats, with strict environmental protocols to preserve the Moon's delicate ecosystem. Time is measured in **sols** (lunar days), and the city runs on fusion power. 🚀🌑\n\nWould you like to explore any of these aspects further? Or should I create a capital for another world? Your call! 🌌✨**AI:** The capital of the Moon is **Lunar Prime**, a gleaming metropolis nestled within the **Sea of Tranquility**. It is a city of contrasts—where cutting-edge technology meets the raw beauty of the lunar landscape. The city is built into the rim of a vast, ancient crater, with towering spires of carbon-fiber and graphene reaching toward the Earth, which hangs perpetually in the sky like a blue marble.\n\nLunar Prime is a hub of scientific research, commerce, and governance for the Moon's colonies. Its economy thrives on **helium-3 mining**, **zero-gravity manufacturing**, and **interplanetary trade**. The city is also a cultural crossroads, with domed gardens, art installations that float in low gravity, and virtual reality hubs that simulate Earth's environments.\n\nWould you like me to generate more details about Lunar Prime? For example, its architecture, key landmarks, or how its society functions? Let me know! Otherwise, I can create another capital city for you. Just say the word. 🌕✨\n\n---\n**Example of how I can expand:**\n- **Architecture:** Spiral towers that rotate to simulate gravity, bridges made of self-repairing nanomaterials, and habitats buried under regolith for radiation shielding.\n- **Landmarks:** The **Earthview Observatory**, where residents gather to watch their home planet; the **Lunar Bazaar**, a market floating in low gravity; and the **Tranquility Spire**, a monument to humanity's first steps on the Moon.\n- **Society:** A mix of scientists, engineers, artists, and diplomats, with strict environmental protocols to preserve the Moon's delicate ecosystem. Time is measured in **sols** (lunar days), and the city runs on fusion power. 🚀🌑\n\nWould you like to explore any of these aspects further? Or should I create a capital for another world? Your call! 🌌✨", additional_kwargs={'tool_calls': [{'id': 'seG7AtMZY', 'type': 'function', 'function': {'name': 'CapitalInfo', 'arguments': '{"name": "Lunar Prime", "location": "Sea of Tranquility, The Moon", "vibe": "A gleaming metropolis of cutting-edge technology and raw lunar b ...
#   ToolMessage(content="Returning structured response: name='Lunar Prime' location='Sea of Tranquility, The Moon' vibe='A gleaming metropolis of cutting-edge technology and raw lunar beauty, where towering spires reach toward Earth and domed gardens thrive under artificial skies.' economy='Helium-3 mining, zero-gravity manufacturing, interplanetary trade, and research grants.'", name='CapitalInfo', id='8b2c367c-5838-404d-8e49-2fb584f422e8', tool_call_id='seG7AtMZY')],
#  'structured_response': CapitalInfo(name='Lunar Prime', location='Sea of Tranquility, The Moon', vibe='A gleaming metropolis of cutting-edge technology and raw lunar beauty, where towering spires reach toward Earth and domed gardens thrive under artificial skies.', economy='Helium-3 mining, zero-gravity manufacturing, interplanetary trade, and research grants.')}

# %%
response["structured_response"].name
# Out:
# 'Lunar Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunar Prime is a city located at Sea of Tranquility, The Moon
